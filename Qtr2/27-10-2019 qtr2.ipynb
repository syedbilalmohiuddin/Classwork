# %%
import numpy as np
import pandas as pd

# %%
import csv
f=open('data.csv')
reader=csv.reader(f)

# %%
for line in reader:
    print(line)
# Out:
# ['Student Code', 'Degree', 'Student Name', 'Mid', 'Quiz 1', 'Quiz 2', 'Best of Quizzes', 'Assignment 1', 'Assignment 2', 'Best of Assignments', 'Total Sessional (50)', 'Final (50)', 'Total (100)', 'Grade']
# ['022-14-19987', 'BS(CS)', 'Abdul Basit', '28', '8', '3', '8', '7', '9', '9', '45', '25', '70', 'B']
# ['022-14-110233', 'BS(CS)', 'Adeel Ahmed', '17', '', '5', '5', '8', '10', '10', '32', '18', '50', 'F']
# ['022-14-110585', 'BS(CS)', 'Afrah Zareen', '18', '5', '2', '5', '8', '10', '10', '33', '30', '63', 'C']
# ['022-14-19718', 'BS(CS)', 'Ahmed Ali Raza', '14', '7', '2', '7', '', '2', '2', '23', '23', '46', 'F']
# ['022-14-110648', 'BS(CS)', 'Ahsan Ali Vohra', '27', '7', '6', '7', '7', '9', '9', '43', '34', '77', 'B']
# ['022-14-110232', 'BS(CS)', 'Ameer Hamza', '25', '9', '6', '9', '8', '10', '10', '44', '27', '71', 'B']
# ['022-14-110588', 'BS(CS)', 'Anas Ali Khan', '28', '5', '6', '6', '8', '10', '10', '44', '30', '74', 'B']
# ['022-14-110388', 'BS(CS)', 'Aneebullah Niazi', '26', '9', '6', '9', '8', '10', '10', '45', '40', '85', 'A']
# ['022-14-110601', 'BS(CS)', 'Areesha Sohail', '19', '9', '4', '9', '7', '9', '9', '37', '24', '61', 'C']
# ['022-14-110599', 'BS(CS)', 'Arsalan', '28', '8', '6', '8', '8', '', '8', '44', '40', '84', 'A']
# ['022-14-110214', 'BS(CS)', 'Fatima Haider Warsi', '30', '8', '7', '8', '8', '', '8', '46', '45', '91', 'A']
# ['022-14-110591', 'BS(CS)', 'Habib Ullah', '28', '8', '5', '8', '5', '', '5', '41', '35', '76', 'B']
# ['022-15-110994', 'BS(CS)', 'Hafiza Tooba Akbani', '23', '7', '5', '7', '8', '10', '10', '40', '33', '73', 'B']
# ['022-14-110600', 'BS(CS)', 'Hamza Abdul Jabbar', '24', '8', '4', '8', '8', '10', '10', '42', '25', '67', 'C']
# ['022-14-110389', 'BS(CS)', 'Hareem Afshan', '21', '7', '4', '7', '6', '8', '8', '36', '29', '65', 'C']
# ['022-14-19916', 'BS(CS)', 'Haseeb Sajid', '18', '', '', '0', '', '', '0', '18', '', '18', 'F']
# ['022-14-110596', 'BS(CS)', 'Hassam Ahmed', '23', '5', '5', '5', '7', '9', '9', '37', '35', '72', 'B']
# ['022-14-110396', 'BS(CS)', 'Khalid Anwer', '20', '8', '5', '8', '9', '11', '11', '39', '31', '70', 'B']
# ['022-14-110223', 'BS(CS)', 'Madiha Jabeen', '16', '5', '2', '5', '8', '10', '10', '31', '29', '60', 'C']
# ['022-14-110222', 'BS(CS)', 'Mohammad Hunain', '27', '9', '6', '9', '8', '10', '10', '46', '45', '91', 'A']
# ['022-14-110412', 'BS(CS)', 'Muhammad Aamir', '24', '7', '6', '7', '7', '9', '9', '40', '31', '71', 'B']
# ['022-14-110593', 'BS(CS)', 'Muhammad Abdul Rehman Siddiqui', '20', '9', '6', '9', '9', '11', '11', '40', '20', '60', 'C']
# ['022-14-110398', 'BS(CS)', 'Muhammad Abdullah', '20', '7', '6', '7', '7', '', '7', '34', '23', '57', 'F']
# ['022-14-19983', 'BS(CS)', 'Muhammad Ali Iqbal', '26', '5', '', '5', '8', '10', '10', '41', '21', '62', 'C']
# ['022-14-110215', 'BS(CS)', 'Muhammad Bilal', '28', '5', '4', '5', '9', '11', '11', '44', '33', '77', 'B']
# ['022-14-110105', 'BS(CS)', 'Muhammad Faraz', '26', '9', '6', '9', '8', '10', '10', '45', '41', '86', 'A']
# ['022-14-110370', 'BS(CS)', 'Muhammad Ghazali Faridi', '27', '6', '', '6', '6', '8', '8', '41', '24', '65', 'C']
# ['022-14-110452', 'BS(CS)', 'Muhammad Osama Khan', '27', '8', '6', '8', '8', '10', '10', '45', '26', '71', 'B']
# ['022-14-110387', 'BS(CS)', 'Muhammad Saqib Intizar', '22', '6', '6', '6', '9', '11', '11', '39', '18', '57', 'F']
# ['022-14-110217', 'BS(CS)', 'Muhammad Shahroz Khurshid', '17', '7', '1', '7', '6', '', '6', '30', '9', '39', 'F']
# ['022-14-110401', 'BS(CS)', 'Muhammad Shozab', '23', '8', '6', '8', '9', '', '9', '40', '32', '72', 'B']
# ['022-14-110231', 'BS(CS)', 'Muhammad Taha Hasnain', '27', '7', '5', '7', '10', '', '10', '44', '29', '73', 'B']
# ['022-14-110035', 'BS(CS)', 'Muhammad Wajahat Khan', '9', '', '2', '2', '8', '10', '10', '21', '8', '29', 'F']
# ['022-14-19919', 'BS(CS)', 'Muhammad Younus Baig', '20', '4', '2', '4', '8', '10', '10', '34', '17', '51', 'F']
# ['022-14-110413', 'BS(CS)', 'Nazeer Bin Zafar', '25', '9', '6', '9', '8', '10', '10', '44', '42', '86', 'A']
# ['022-14-19923', 'BS(CS)', 'Rabi Ahmed', '20', '8', '5', '8', '', '10', '10', '38', '28', '66', 'C']
# ['022-14-110582', 'BS(CS)', 'Rida Nasim', '25', '9', '5', '9', '9', '', '9', '43', '27', '70', 'B']
# ['022-14-110230', 'BS(CS)', 'Sadaf Nosheen', '27', '9', '5', '9', '9', '', '9', '45', '30', '75', 'B']
# ['022-14-110229', 'BS(CS)', 'Sadaquat Rafique', '9', '6', '6', '6', '5', '7', '7', '22', '17', '39', 'F']
# ['022-14-110107', 'BS(CS)', 'Sania Iqbal', '28', '4', '4', '4', '9', '11', '11', '43', '25', '68', 'C']
# ['022-14-110584', 'BS(CS)', 'Sharif Taqi', '27', '9', '6', '9', '8', '10', '10', '46', '35', '81', 'A']
# ['022-14-110225', 'BS(CS)', 'Shariqa Ahmad', '20', '7', '6', '7', '8', '10', '10', '37', '20', '57', 'F']
# ['022-14-110587', 'BS(CS)', 'Sumbul Rehman', '28', '5', '6', '6', '8', '10', '10', '44', '23', '67', 'C']
# ['022-14-110451', 'BS(CS)', 'Syed Faizan Uddin', '28', '9', '4', '9', '6', '8', '8', '45', '34', '79', 'B']
# ['022-14-110589', 'BS(CS)', 'Syed Sohaib', '25', '7', '5', '7', '9', '', '9', '41', '22', '63', 'C']
# ['022-14-110400', 'BS(CS)', 'Syeda Sabika Raza', '27', '9', '6', '9', '9', '', '9', '45', '35', '80', 'A']
# ['022-14-19911', 'BS(CS)', 'Usman Khan', '25', '8', '5', '8', '8', '10', '10', '43', '22', '65', 'C']
# ['022-14-110219', 'BS(CS)', 'Waqar Ahmed', '11', '9', '5', '9', '5', '7', '7', '27', '19', '46', 'F']

# %%
with open('data.csv') as f:
    lines=list(csv.reader(f))
#lines

# %%
header,values=lines[0],lines[1:]
data_dict={h: v for h, v in zip(header,zip(*values))}
#data_dict

# %%
import sys
data.to_csv(sys.stdout,sep='|')
|something|a|b|c|d|message
# 0|one|1|2|3|4|
# Out:
#   File "<ipython-input-26-79e67886dc28>", line 3
#     |something|a|b|c|d|message
#     ^
# SyntaxError: invalid syntax

# %%
x=[1,2,3,4,5,6,7,8]
y=[2,4,6,8,10,12,14,16,18]
z=[3,6,9,12,15,18,21,24,27,30,33]
zipp=zip(x,y,z)

# %%
for val in zipp:
    print(val)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-90adeb4f5125> in <module>
# ----> 1 for val in zipp:
#       2     print(val)
#
# NameError: name 'zipp' is not defined

# %%
x=['ali','amir'] #packing
x
# Out:
# ['ali', 'amir']

# %%
#Web Scraping
import lxml
 
tables=pd.read_html('fdic_failed_bank_list.html')
tables
len(tables)
# Out:
#                       Bank Name             City  ST   CERT  \
# 0                   Allied Bank         Mulberry  AR     91
# 1  The Woodbury Banking Company         Woodbury  GA  11297
# 2        First CornerStone Bank  King of Prussia  PA  35312
# 3            Trust Company Bank          Memphis  TN   9956
# 4    North Milwaukee State Bank        Milwaukee  WI  20364
#
#                  Acquiring Institution        Closing Date       Updated Date
# 0                         Today's Bank  September 23, 2016  November 17, 2016
# 1                          United Bank     August 19, 2016  November 17, 2016
# 2  First-Citizens Bank & Trust Company         May 6, 2016  September 6, 2016
# 3           The Bank of Fayette County      April 29, 2016  September 6, 2016
# 4  First-Citizens Bank & Trust Company      March 11, 2016      June 16, 2016

# %%
failures = tables[0]
failures.head()
# Out:
#                       Bank Name             City  ST   CERT  \
# 0                   Allied Bank         Mulberry  AR     91
# 1  The Woodbury Banking Company         Woodbury  GA  11297
# 2        First CornerStone Bank  King of Prussia  PA  35312
# 3            Trust Company Bank          Memphis  TN   9956
# 4    North Milwaukee State Bank        Milwaukee  WI  20364
#
#                  Acquiring Institution        Closing Date       Updated Date
# 0                         Today's Bank  September 23, 2016  November 17, 2016
# 1                          United Bank     August 19, 2016  November 17, 2016
# 2  First-Citizens Bank & Trust Company         May 6, 2016  September 6, 2016
# 3           The Bank of Fayette County      April 29, 2016  September 6, 2016
# 4  First-Citizens Bank & Trust Company      March 11, 2016      June 16, 2016

# %%
close_timestamps = pd.to_datetime(failures['Closing Date'])
yearcount=close_timestamps.dt.year.value_counts()
monthcount=close_timestamps.dt.month.value_counts()
daycount=close_timestamps.dt.day.value_counts()
datecount=close_timestamps.dt.date.value_counts()
daycount
# Out:
# 23    31
# 30    30
# 19    30
# 20    27
# 17    23
# 16    22
# 4     21
# 18    21
# 7     20
# 15    20
# 2     20
# 14    20
# 24    19
# 28    18
# 27    18
# 22    18
# 11    18
# 21    17
# 29    16
# 26    15
# 5     15
# 13    14
# 10    14
# 8     14
# 6     14
# 25    13
# 12    10
# 9     10
# 31     8
# 1      8
# 3      3
# Name: Closing Date, dtype: int64

# %%
#api
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
data[0]['title']
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29241',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29241/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29241/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29241/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/29241',
#   'id': 512980469,
#   'node_id': 'MDU6SXNzdWU1MTI5ODA0Njk=',
#   'number': 29241,
#   'title': 'merge vs. join - unify parameter names',
#   'user': {'login': 'stefansimik',
#    'id': 6208056,
#    'node_id': 'MDQ6VXNlcjYyMDgwNTY=',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/6208056?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stefansimik',
#    'html_url': 'https://github.com/stefansimik',
#    'followers_url': 'https://api.github.com/users/stefansimik/followers',
#    'following_url': 'https://api.github.com/users/stefansimik/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/stefansimik/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/stefansimik/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/stefansimik/subscriptions',
#    'organizations_url': 'https://api.github.com/users/stefansimik/orgs',
#    'repos_url': 'https://api.github.com/users/stefansimik/repos',
#    'events_url': 'https://api.github.com/users/stefansimik/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/stefansimik/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-10-27T15:23:52Z',
#   'updated_at': '2019-10-27T15:37:27Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'body': "#### Problem description\r\n\r\n`pandas.DataFrame.merge` function is conceptually simillar like `pandas.DataFrame.join` function.\r\n(first one one merges on specified columns, second merges on index).\r\n\r\nThese 2 functions use various parameters to do the same thing:\r\n* `join` function has 2 params:  `lsuffix + rsuffix`\r\n* `merge` function has only 1 param: `suffixes`\r\n\r\nWe should unify names and usage of these parameter(s).\r\nLet's use first way or second way, and deprecate the other way.\r\n\r\n_(Personally, I prefer to have only 1 param `suffixes` as it is shorter and there is 1 param for 1 purpose)._\r\n#### Expected Output\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : None\r\npython           : 3.7.4.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 7\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 79 Stepping 1, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : None.None\r\n\r\npandas           : 0.25.2\r\nnumpy            : 1.16.5\r\npytz             : 2019.3\r\ndateutil         : 2.8.0\r\npip              : 19.2.3\r\nsetuptools       : 41.4.0\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.4.1\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.10.3\r\nIPython          : 7.8.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfastparquet      : None\r\ngcsfs            : None\r\nlxml.etree       : 4.4.1\r\nmatplotlib       : 3.1.1\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.0\r\npandas_gbq       : None\r\npyarrow          : 0.14.1\r\npytables         : None\r\ns3fs             : None\r\nscipy            : 1.3.1\r\nsqlalchemy       : None\r\ntables           : None\r\nxarray           : None\r\nxlrd             : 1.2.0\r\nxlwt             : None\r\nxlsxwriter       : None\r\n\r\n</details>\r\n"},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29240',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29240/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29240/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29240/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/29240',
#   'id': 512907508,
#   'node_id': 'MDU6SXNzdWU1MTI5MDc1MDg=',
#   'number': 29240,
#   'title': 'Trying to use to_sql on dataframe with numpy.ndarray columns causes ValueError',
#   'user': {'login': 'kjfergu',
#    'id': 9022843,
#    'node_id': 'MDQ6VXNlcjkwMjI4NDM=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/9022843?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kjfergu',
#    'html_url': 'https://github.com/kjfergu',
#    'followers_url': 'https://api.github.com/users/kjfergu/followers',
#    'following_url': 'https://api.github.com/users/kjfergu/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kjfergu/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kjfergu/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kjfergu/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kjfergu/orgs',
#    'repos_url': 'https://api.github.com/users/kjfergu/repos',
#    'events_url': 'https://api.github.com/users/kjfergu/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kjfergu/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2019-10-27T01:44:31Z',
#   'updated_at': '2019-10-27T06:04:42Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'body': 'I am trying out using pandas+sqlalchemy (specifically sqlite) as a means to store my data. In my use case, I will have a number of rows where most will be obvious types such as string, int, float, etc - but I will want to store a few numpy ndarrays. In the example below, each \'channel\' entry is a 1x3000 array of floats. For higher dimensional arrays (at most 2D) I plan to store the shape of the data alongside the flattened array, so this is all I need.\r\n\r\n#### Code Sample, a copy-pastable example if possible\r\n\r\nThis was run in Jupyter Lab.\r\n\r\n```python\r\nimport sqlalchemy\r\nimport numpy as np\r\nimport pandas as pd\r\n\r\nengine = sqlalchemy.create_engine(\'sqlite:///:memory:\')\r\nallPts = []\r\n\r\nfor i in range(0,30):\r\n    name = "R"+str(i).zfill(3)\r\n    start = np.random.rand()\r\n    end = np.random.rand()\r\n    data = np.random.random((4,3000))\r\n    thisDict = {\'name\':name,\'start\':start,\'end\':end,\'channel1\':data[:,0],\'channel2\':data[:,1],\'channel3\':data[:,2],\'channel4\':data[:,3]}\r\n    allPts.append(pd.Series(thisDict))\r\nasDF = pd.DataFrame(allPts)\r\nasDF.to_sql(\'dftest\',engine,if_exists=\'replace\')\r\n```\r\n\r\nThis produces the traceback\r\n\r\n```\r\n---------------------------------------------------------------------------\r\nValueError                                Traceback (most recent call last)\r\n<ipython-input-30-e1fb02c5da64> in <module>\r\n----> 1 asDF.to_sql(\'dftest\',engine,if_exists=\'replace\')\r\n\r\nc:\\users\\(me)\\documents\\pyenv\\dataproc\\lib\\site-packages\\pandas\\core\\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)\r\n   2710             chunksize=chunksize,\r\n   2711             dtype=dtype,\r\n-> 2712             method=method,\r\n   2713         )\r\n   2714 \r\n\r\nc:\\users\\(me)\\documents\\pyenv\\dataproc\\lib\\site-packages\\pandas\\io\\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)\r\n    516         chunksize=chunksize,\r\n    517         dtype=dtype,\r\n--> 518         method=method,\r\n    519     )\r\n    520 \r\n\r\nc:\\users\\(me)\\documents\\pyenv\\dataproc\\lib\\site-packages\\pandas\\io\\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)\r\n   1318         )\r\n   1319         table.create()\r\n-> 1320         table.insert(chunksize, method=method)\r\n   1321         if not name.isdigit() and not name.islower():\r\n   1322             # check for potentially case sensitivity issues (GH7815)\r\n\r\nc:\\users\\(me)\\documents\\pyenv\\dataproc\\lib\\site-packages\\pandas\\io\\sql.py in insert(self, chunksize, method)\r\n    754 \r\n    755                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])\r\n--> 756                 exec_insert(conn, keys, chunk_iter)\r\n    757 \r\n    758     def _query_iterator(\r\n\r\nc:\\users\\(me)\\documents\\pyenv\\dataproc\\lib\\site-packages\\pandas\\io\\sql.py in _execute_insert(self, conn, keys, data_iter)\r\n    668         """\r\n    669         data = [dict(zip(keys, row)) for row in data_iter]\r\n--> 670         conn.execute(self.table.insert(), data)\r\n    671 \r\n    672     def _execute_insert_multi(self, conn, keys, data_iter):\r\n\r\nc:\\users\\(me)\\documents\\pyenv\\dataproc\\lib\\site-packages\\sqlalchemy\\engine\\base.py in execute(self, object_, *multiparams, **params)\r\n    986             raise exc.ObjectNotExecutableError(object_)\r\n    987         else:\r\n--> 988             return meth(self, multiparams, params)\r\n    989 \r\n    990     def _execute_function(self, func, multiparams, params):\r\n\r\nc:\\users\\(me)\\documents\\pyenv\\dataproc\\lib\\site-packages\\sqlalchemy\\sql\\elements.py in _execute_on_connection(self, connection, multiparams, params)\r\n    285     def _execute_on_connection(self, connection, multiparams, params):\r\n    286         if self.supports_execution:\r\n- ...
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29239',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29239/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29239/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29239/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/29239',
#   'id': 512885663,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0MzMyODAxNzE4',
#   'number': 29239,
#   'title': 'BENCH: Improve perf of rolling.Apply.time_rolling',
#   'user': {'login': 'qwhelan',
#    'id': 440095,
#    'node_id': 'MDQ6VXNlcjQ0MDA5NQ==',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/440095?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/qwhelan',
#    'html_url': 'https://github.com/qwhelan',
#    'followers_url': 'https://api.github.com/users/qwhelan/followers',
#    'following_url': 'https://api.github.com/users/qwhelan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/qwhelan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/qwhelan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/qwhelan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/qwhelan/orgs',
#    'repos_url': 'https://api.github.com/users/qwhelan/repos',
#    'events_url': 'https://api.github.com/users/qwhelan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/qwhelan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-10-26T21:06:21Z',
#   'updated_at': '2019-10-26T21:06:21Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/29239',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/29239',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/29239.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/29239.patch'},
#   'body': 'Per discussion in #29165, this PR significantly reduces the run time of the `rolling.Apply.time_rolling` benchmark from 8 minutes minimum.\r\n```\r\n$ asv dev -b rolling.Apply.time_rolling\r\n· Discovering benchmarks\r\n· Running 1 total benchmarks (1 commits * 1 environments * 1 benchmarks)\r\n[  0.00%] ·· Benchmarking existing-py_home_chris_anaconda3_bin_python\r\n[ 50.00%] ··· Running (rolling.Apply.time_rolling--).\r\n[100.00%] ··· rolling.Apply.time_rolling                                                                                                                                                                  ok\r\n[100.00%] ··· ============= ======== ======= =========================== ============= ============\r\n              --                                                                    raw            \r\n              ---------------------------------------------------------- --------------------------\r\n               constructor   window   dtype            function               True        False    \r\n              ============= ======== ======= =========================== ============= ============\r\n                DataFrame      3       int     <built-in function sum>     1.87±0.1ms    44.8±2ms  \r\n                DataFrame      3       int          <function sum>         3.53±0.2ms    126±3ms   \r\n                DataFrame      3       int    <function Apply.<lambda>>    4.20±0.2ms    126±7ms   \r\n                DataFrame      3      float    <built-in function sum>    1.86±0.07ms    45.1±1ms  \r\n                DataFrame      3      float         <function sum>        3.42±0.03ms    129±5ms   \r\n                DataFrame      3      float   <function Apply.<lambda>>    4.34±0.5ms    133±9ms   \r\n                DataFrame     300      int     <built-in function sum>      31.8±3ms     44.1±2ms  \r\n                DataFrame     300      int          <function sum>         2.90±0.2ms   92.6±10ms  \r\n                DataFrame     300      int    <function Apply.<lambda>>    3.24±0.2ms    93.9±4ms  \r\n                DataFrame     300     float    <built-in function sum>     33.3±20ms    85.4±40ms  \r\n                DataFrame     300     float         <function sum>         3.06±0.3ms    91.0±3ms  \r\n                DataFrame     300     float   <function Apply.<lambda>>    3.19±0.2ms    91.5±4ms  \r\n                  Series       3       int     <built-in function sum>    1.42±0.03ms    43.6±1ms  \r\n                  Series       3       int          <function sum>        3.08±0.06ms    127±2ms   \r\n                  Series       3       int    <function Apply.<lambda>>    3.67±0.2ms    127±20ms  \r\n                  Series       3      float    <built-in function sum>    1.41±0.03ms   43.5±0.5ms \r\n                  Series       3      float         <function sum>         3.08±0.1ms    123±3ms   \r\n                  Series       3      float   <function Apply.<lambda>>    3.65±0.1ms    129±6ms   \r\n                  Series      300      int     <built-in function sum>      31.2±2ms     43.8±3ms  \r\n                  Series      300      int          <function sum>         2.35±0.1ms    90.4±4ms  \r\n                  Series      300      int    <function Apply.<lambda>>    2.74±0.2ms    93.2±6ms  \r\n                  Series      300     float    <built-in function sum>     31.7±0.8ms    45.6±1ms  \r\n                  Series      300     float         <function sum>         2.36±0.1ms    108±20ms  \r\n                  Series      300     float   <function Apply.<lambda>>   2.82±0.09ms    99.4±2ms  \r\n              ============= ======== ======= =========================== ============= ============\r\n```\r\n\r\n- [ ] closes #xxxx\r\n- [ ] tests added / passed\r\n- [ ] passes `black pandas`\r\n- [ ] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [ ] whatsnew entry\r\n'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29237',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29237/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29237/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29237/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/29237',
#   'id': 512837731,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0MzMyNzY4NDMy',
#   'number': 29237,
#   'title': 'Replace _has_complex_internals #29227',
#   'user': {'login': 'Aivengoe',
#    'id': 18753654,
#    'node_id': 'MDQ6VXNlcjE4NzUzNjU0',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/18753654?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Aivengoe',
#    'html_url': 'https://github.com/Aivengoe',
#    'followers_url': 'https://api.github.com/users/Aivengoe/followers',
#    'following_url': 'https://api.github.com/users/Aivengoe/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Aivengoe/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Aivengoe/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Aivengoe/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Aivengoe/orgs',
#    'repos_url': 'https://api.github.com/users/Aivengoe/repos',
#    'events_url': 'https://api.github.com/users/Aivengoe/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Aivengoe/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2019-10-26T13:49:24Z',
#   'updated_at': '2019-10-26T16:37:34Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/29237',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/29237',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/29237.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/29237.patch'},
#   'body': 'closes #29227\r\n\r\nHi, it my first issues within hacktoberfest. \r\nI replaced _has_complex_internals with isinstance/\r\nIs it possible to import ABCMultiIndex?\r\n'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29236',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29236/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29236/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29236/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/29236',
#   'id': 512831616,
#   'node_id': 'MDU6SXNzdWU1MTI4MzE2MTY=',
#   'number': 29236,
#   'title': 'DOCS: Formatting Errors pandas.TimedeltaIndex',
#   'user': {'login': 'HughKelley',
#    'id': 38143549,
#    'node_id': 'MDQ6VXNlcjM4MTQzNTQ5',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/38143549?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/HughKelley',
#    'html_url': 'https://github.com/HughKelley',
#    'followers_url': 'https://api.github.com/users/HughKelley/followers',
#    'following_url': 'https://api.github.com/users/HughKelley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/HughKelley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/HughKelley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/HughKelley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/HughKelley/orgs',
#    'repos_url': 'https://api.github.com/users/HughKelley/repos',
#    'events_url': 'https://api.github.com/users/HughKelley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/HughKelley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-10-26T12:47:00Z',
#   'updated_at': '2019-10-26T12:55:42Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'body': '[pandas/core/Indexes/timedeltas.py](https://github.com/pandas-dev/pandas/blob/c7462edc33e89452ae55cb52f61b23cb66e48a5b/pandas/core/indexes/timedeltas.py)\r\n\r\n#28602 \r\n#27977\r\n\r\n\r\n[pandas/core/indexes/base.py](https://github.com/pandas-dev/pandas/blob/0a44feafd58f3c5576e5f4bf3d0136dcacc352f2/pandas/core/indexes/base.py)\r\n\r\n```\r\npython ./scripts/validate_docstrings.py pandas.TimedeltaIndex.to_series\r\n```\r\n\r\n```\r\n7 Errors found:\r\n\tSummary should fit in a single line\r\n\tParameter "index" description should start with a capital letter\r\n\tParameter "index" description should finish with "."\r\n\tParameter "name" description should start with a capital letter\r\n\tParameter "name" description should finish with "."\r\n\tThe first line of the Returns section should contain only the type, unless multiple values are being returned\r\n\tReturn value has no description\r\n```\r\n\r\n\r\n\r\n[pandas/core/arrays/datetime.py](https://github.com/pandas-dev/pandas/blob/18a9e4c8ab253e83ba43767d890576186be13332/pandas/core/arrays/datetimelike.py)\r\n```\r\n./scripts/validate_docstrings.py pandas.TimedeltaIndex.mean\r\n```\r\n\r\n```\r\n5 Errors found:\r\n\tParameters {**kwargs, *args} not documented\r\n\tUnknown parameters {skipna}\r\n\tParameter "skipna" description should finish with "."\r\n\tReturn value has no description\r\n\tMissing description for See Also "numpy.ndarray.mean" reference\r\n```\r\n'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29235',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29235/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29235/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29235/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/29235',
#   'id': 512820850,
#   'node_id': 'MDU6SXNzdWU1MTI4MjA4NTA=',
#   'number': 29235,
#   'title': 'Categories reordered to alphabetical when plotting histograms',
#   'user': {'login': 'dmey',
#    'id': 26348635,
#    'node_id': 'MDQ6VXNlcjI2MzQ4NjM1',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/26348635?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dmey',
#    'html_url': 'https://github.com/dmey',
#    'followers_url': 'https://api.github.com/users/dmey/followers',
#    'following_url': 'https://api.github.com/users/dmey/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dmey/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dmey/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dmey/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dmey/orgs',
#    'repos_url': 'https://api.github.com/users/dmey/repos',
#    'events_url': 'https://api.github.com/users/dmey/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/dmey/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 78527356,
#     'node_id': 'MDU6TGFiZWw3ODUyNzM1Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Categorical',
#     'name': 'Categorical',
#     'color': 'e11d21',
#     'default': False},
#    {'id': 2413328,
#     'node_id': 'MDU6TGFiZWwyNDEzMzI4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Visualization',
#     'name': 'Visualization',
#     'color': '8AE234',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-10-26T10:44:24Z',
#   'updated_at': '2019-10-26T16:27:39Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'body': "#### Code Sample, a copy-pastable example if possible\r\n\r\n```python\r\nimport pandas as pd\r\n\r\nimport matplotlib.pyplot as plt\r\n\r\ndf = pd.DataFrame({\r\n    'width': [0.7, 0.2, 0.15, 0.2, 1.1],\r\n    'length': [1.5, 0.5, 1.2, 0.9, 3]\r\n    }, index= ['pig', 'rabbit', 'duck', 'chicken', 'horse'])\r\n\r\n# Whether or not `column` is passed the order is still reordered to alphabetical.\r\ndf.hist(column=['width','length'])\r\nplt.show()\r\n```\r\n#### Problem description\r\n\r\nWhen plotting histograms from a DataFrame (see code-snippet above) the order of subplots is not maintained. Passing `column` does not appear to have any effect on the ordering either. \r\n\r\n\r\n#### Expected Output\r\n\r\nPlots/subplots order equals column order in DataFrame.\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit: None\r\npython: 3.7.3.final.0\r\npython-bits: 64\r\nOS: Windows\r\nOS-release: 10\r\nmachine: AMD64\r\nprocessor: Intel64 Family 6 Model 69 Stepping 1, GenuineIntel\r\nbyteorder: little\r\nLC_ALL: None\r\nLANG: None\r\nLOCALE: None.None\r\n\r\npandas: 0.24.2\r\npytest: 5.2.1\r\npip: 19.1.1\r\nsetuptools: 41.0.1\r\nCython: None\r\nnumpy: 1.16.4\r\nscipy: 1.2.2\r\npyarrow: None\r\nxarray: 0.12.1\r\nIPython: 7.5.0\r\nsphinx: None\r\npatsy: 0.5.1\r\ndateutil: 2.8.0\r\npytz: 2019.1\r\nblosc: None\r\nbottleneck: None\r\ntables: None\r\nnumexpr: None\r\nfeather: None\r\nmatplotlib: 3.1.0\r\nopenpyxl: None\r\nxlrd: None\r\nxlwt: None\r\nxlsxwriter: None\r\nlxml.etree: None\r\nbs4: 4.7.1\r\nhtml5lib: None\r\nsqlalchemy: None\r\npymysql: None\r\npsycopg2: None\r\njinja2: 2.10.1\r\ns3fs: None\r\nfastparquet: None\r\npandas_gbq: None\r\npandas_datareader: None\r\ngcsfs: None\r\n```\r\n"},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29234',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29234/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29234/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29234/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/29234',
#   'id': 512794116,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0MzMyNzM4Mjg2',
#   'number': 29234,
#   'title': "BUG: PeriodEngine doesn't work",
#   'user': {'login': 'proost',
#    'id': 34047134,
#    'node_id': 'MDQ6VXNlcjM0MDQ3MTM0',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/34047134?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/proost',
#    'html_url': 'https://github.com/proost',
#    'followers_url': 'https://api.github.com/users/proost/followers',
#    'following_url': 'https://api.github.com/users/proost/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/proost/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/proost/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/proost/subscriptions',
#    'organizations_url': 'https://api.github.com/users/proost/orgs',
#    'repos_url': 'https://api.github.com/users/proost/repos',
#    'events_url': 'https://api.github.com/users/proost/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/proost/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2019-10-26T05:34:34Z',
#   'updated_at': '2019-10-26T16:45:26Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/29234',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/29234',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/29234.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/29234.patch'},
#   'body': '- [x] closes #29038\r\n- [x] tests added / passed\r\n- [x] passes `black pandas`\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [x] whatsnew entry\r\n\r\nxref #28628. \r\nI want to refactor `PeriodIndex.get_loc`. Because `PeriodIndex.get_loc` compute twice `Int64index.get_loc` and `PeriodEngine.get_loc`. Problem is only `PeriodEngine.get_loc` accepts `Period.ordinal`. \r\nI try to change `PeriodIndex.get_loc` in two ways.\r\nFirst one, I try to remove `PeriodEngine.get_loc` in `PeriodIndex.get_loc`. so just compute `.get_loc` once. I change several ways But always stuck in test cases. So I give it up this way.\r\nSecond one, I try to change `PeriodEngine.get_loc` to accept `Period` not only `Period.ordinal`. This way is success in that work successfully and pass all test cases. However Problem is most cases users don\'t use `Period` using `PeriodIndex.get_loc` and `PeriodEngine.get_loc` can\'t accept "intolerance" argument. Not using `Int64index.get_loc` can\'t be possible. \r\nBut I send PR. Little improvement is also improvement. '},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29233',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29233/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29233/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29233/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/29233',
#   'id': 512792675,
#   'node_id': 'MDU6SXNzdWU1MTI3OTI2NzU=',
#   'number': 29233,
#   'title': 'read_csv encode operation on source',
#   'user': {'login': 'abellerarj',
#    'id': 56994226,
#    'node_id': 'MDQ6VXNlcjU2OTk0MjI2',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/56994226?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/abellerarj',
#    'html_url': 'https://github.com/abellerarj',
#    'followers_url': 'https://api.github.com/users/abellerarj/followers',
#    'following_url': 'https://api.github.com/users/abellerarj/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/abellerarj/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/abellerarj/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/abellerarj/subscriptions',
#    'organizations_url': 'https://api.github.com/users/abellerarj/orgs',
#    'repos_url': 'https://api.github.com/users/abellerarj/repos',
#    'events_url': 'https://api.github.com/users/abellerarj/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/abellerarj/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 47229171,
#     'node_id': 'MDU6TGFiZWw0NzIyOTE3MQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20CSV',
#     'name': 'IO CSV',
#     'color': '5319e7',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-10-26T05:14:57Z',
#   'updated_at': '2019-10-26T16:28:28Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'body': '#### Code Sample, a copy-pastable example if possible\r\n\r\n```python\r\n>>> import pandas as pd\r\n>>> df = pd.read_csv("historical_dataset.csv")\r\nTraceback (most recent call last):\r\n  File "<stdin>", line 1, in <module>\r\n  File "/usr/lib/python3/dist-packages/pandas/io/parsers.py", line 709, in parser_f\r\n    return _read(filepath_or_buffer, kwds)\r\n  File "/usr/lib/python3/dist-packages/pandas/io/parsers.py", line 449, in _read\r\n    parser = TextFileReader(filepath_or_buffer, **kwds)\r\n  File "/usr/lib/python3/dist-packages/pandas/io/parsers.py", line 818, in __init__\r\n    self._make_engine(self.engine)\r\n  File "/usr/lib/python3/dist-packages/pandas/io/parsers.py", line 1049, in _make_engine\r\n    self._engine = CParserWrapper(self.f, **self.options)\r\n  File "/usr/lib/python3/dist-packages/pandas/io/parsers.py", line 1695, in __init__\r\n    self._reader = parsers.TextReader(src, **kwds)\r\n  File "pandas/_libs/parsers.pyx", line 402, in pandas._libs.parsers.TextReader.__cinit__\r\n  File "pandas/_libs/parsers.pyx", line 718, in pandas._libs.parsers.TextReader._setup_parser_source\r\nFileNotFoundError: File b\'historical_dataset.csv\' does not exist\r\n```\r\n#### Problem description\r\n\r\nNoticed that when source does not exist, there is a leading \'b\' on the source on the error message. For Python3, is it necessary to do the encode operation on line 667 of https://github.com/pandas-dev/pandas/blob/master/pandas/_libs/parsers.pyx? Works fine for Python2.\r\n\r\n#### Output of ``pd.show_versions()``\r\n<details>\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : None\r\npython           : 3.7.4.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.0.0-31-generic\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : en_US.UTF-8\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 0.25.1\r\nnumpy            : 1.14.5\r\npytz             : 2018.5\r\ndateutil         : 2.8.0\r\npip              : 19.2.3\r\nsetuptools       : 41.2.0\r\nCython           : 0.29.13\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : 1.7.6\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.2.3\r\nhtml5lib         : None\r\npymysql          : 0.9.3\r\npsycopg2         : None\r\njinja2           : 2.10\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfastparquet      : None\r\ngcsfs            : None\r\nlxml.etree       : 4.2.3\r\nmatplotlib       : 2.2.2\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npytables         : None\r\ns3fs             : None\r\nscipy            : 1.1.0\r\nsqlalchemy       : 1.3.8\r\ntables           : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nxlsxwriter       : None\r\n```\r\n</details>'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29232',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29232/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29232/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29232/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/29232',
#   'id': 512773525,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0MzMyNzIzNTM3',
#   'number': 29232,
#   'title': 'CLN: assorted cleanups',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-10-26T01:21:52Z',
#   'updated_at': '2019-10-26T01:21:52Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/29232',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/29232',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/29232.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/29232.patch'},
#   'body': ''},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29229',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29229/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29229/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29229/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/29229',
#   'id': 512679300,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0MzMyNjQ2NDY0',
#   'number': 29229,
#   'title': 'API/DOC: an ExtensionDtype.__from_arrow__ method to convert pyarrow.Array into ExtensionArray',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76865106,
#     'node_id': 'MDU6TGFiZWw3Njg2NTEwNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Compat',
#     'name': 'Compat',
#     'color': '0052cc',
#     'default': False},
#    {'id': 849023693,
#     'node_id': 'MDU6TGFiZWw4NDkwMjM2OTM=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/ExtensionArray',
#     'name': 'ExtensionArray',
#     'color': '6138b5',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2019-10-25T19:21:18Z',
#   'updated_at': '2019-10-26T11:15:35Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/29229',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/29229',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/29229.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/29229.patch'},
#   'body': 'xref the discussion in https://github.com/pandas-dev/pandas/issues/20612, and a companion to my PR in Arrow: https://github.com/apache/arrow/pull/5512\r\n\r\nSummary: to support ExtensionArrays in the conversion of an arrow table into a pandas DataFrame, we need some way to convert pyarrow Arrays into pandas ExtensionArrays, given a certain pandas dtype (in pyarrow, we can for example know the resulting dtype from the stored metadata).\r\n\r\nFor that, I propose to add the `ExtensionDtype.__from_arrow__` method, with the following signature:\r\n\r\n```\r\nclass ExtensionDtype:\r\n\r\n    def __from_arrow__(self, array: pyarrow.Array) -> pandas.ExtensionArray:\r\n        ...\r\n```\r\n\r\nNote: I only added documentation about it (which should still be expanded) for now, and not a method in the base class (eg a NotImplementedError), because in pyarrow we use `hasattr` to see if this is supported (see the linked arrow PR).'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29228',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29228/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29228/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29228/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/29228',
#   'id': 512645969,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0MzMyNjE4ODQ2',
#   'number': 29228,
#   'title': 'CLN: prevent libreduction TypeError',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-10-25T18:03:35Z',
#   'updated_at': '2019-10-25T21:29:03Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/29228',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/29228',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/29228.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/29228.patch'},
#   'body': 'cc @jreback @WillAyd '},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29227',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29227/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29227/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29227/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/29227',
#   'id': 512626076,
#   'node_id': 'MDU6SXNzdWU1MTI2MjYwNzY=',
#   'number': 29227,
#   'title': 'Replace _has_complex_internals with isinstance(..., ABCMultiIndex)',
#   'user': {'login': 'WillAyd',
#    'id': 609873,
#    'node_id': 'MDQ6VXNlcjYwOTg3Mw==',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/609873?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/WillAyd',
#    'html_url': 'https://github.com/WillAyd',
#    'followers_url': 'https://api.github.com/users/WillAyd/followers',
#    'following_url': 'https://api.github.com/users/WillAyd/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/WillAyd/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/WillAyd/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/WillAyd/subscriptions',
#    'organizations_url': 'https://api.github.com/users/WillAyd/orgs',
#    'repos_url': 'https://api.github.com/users/WillAyd/repos',
#    'events_url': 'https://api.github.com/users/WillAyd/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/WillAyd/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-10-25T17:13:32Z',
#   'updated_at': '2019-10-25T17:13:32Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'body': "I've stumbled across this code a few times in groupby and it took me a while to grasp. I'm pretty sure this always evaluates to False, unless we are dealing with a MultiIndex.\r\n\r\nFor code clarity, I think it would be better if we just did an isinstance check as I don't think the intent of `_has_complex_internals` is very clear"},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29226',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29226/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29226/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29226/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/29226',
#   'id': 512600168,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0MzMyNTgyMDEx',
#   'number': 29226,
#   'title': 'Remove TestData in frame tests in multiple files - part 3',
#   'user': {'login': 'SaturnFromTitan',
#    'id': 17853006,
#    'node_id': 'MDQ6VXNlcjE3ODUzMDA2',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/17853006?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SaturnFromTitan',
#    'html_url': 'https://github.com/SaturnFromTitan',
#    'followers_url': 'https://api.github.com/users/SaturnFromTitan/followers',
#    'following_url': 'https://api.github.com/users/SaturnFromTitan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/SaturnFromTitan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/SaturnFromTitan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/SaturnFromTitan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/SaturnFromTitan/orgs',
#    'repos_url': 'https://api.github.com/users/SaturnFromTitan/repos',
#    'events_url': 'https://api.github.com/users/SaturnFromTitan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/SaturnFromTitan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-10-25T16:10:22Z',
#   'updated_at': '2019-10-26T10:03:51Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/29226',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/29226',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/29226.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/29226.patch'},
# ...
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29203',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29203/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29203/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29203/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/29203',
#   'id': 511923432,
#   'node_id': 'MDU6SXNzdWU1MTE5MjM0MzI=',
#   'number': 29203,
#   'title': 'Improve docs on what the axis= kwarg does in individual functions/methods',
#   'user': {'login': 'dlukes',
#    'id': 2734517,
#    'node_id': 'MDQ6VXNlcjI3MzQ1MTc=',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/2734517?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dlukes',
#    'html_url': 'https://github.com/dlukes',
#    'followers_url': 'https://api.github.com/users/dlukes/followers',
#    'following_url': 'https://api.github.com/users/dlukes/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dlukes/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dlukes/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dlukes/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dlukes/orgs',
#    'repos_url': 'https://api.github.com/users/dlukes/repos',
#    'events_url': 'https://api.github.com/users/dlukes/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/dlukes/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False},
#    {'id': 307649777,
#     'node_id': 'MDU6TGFiZWwzMDc2NDk3Nzc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Info',
#     'name': 'Needs Info',
#     'color': '207de5',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2019-10-24T12:50:52Z',
#   'updated_at': '2019-10-25T07:53:34Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'body': '### `axis=0` or `axis=1`, which is it?\r\n\r\nI\'ve always found it hard to remember which axis (`0/"index"` vs. `1/"columns"`) does what for various operations. I suppose some people find it intuitive, while others (like me) find it confusing and inconsistent.\r\n\r\nCase in point, `DataFrame.sum` vs. `DataFrame.drop`: if I want **column sums**, I need `axis=0`...\r\n\r\n```python\r\n>>> import pandas as pd\r\n>>> df = pd.DataFrame(dict(a=[1, 2, 3], b=[4, 5, 6]))\r\n>>> df\r\n   a  b\r\n0  1  4\r\n1  2  5\r\n2  3  6\r\n>>> df.sum(axis=0)\r\na     6\r\nb    15\r\ndtype: int64\r\n```\r\n\r\n... but if I want to **drop a column**, I need `axis=1`:\r\n\r\n```python\r\n>>> df.drop("a", axis=1)\r\n   b\r\n0  4\r\n1  5\r\n2  6\r\n```\r\n\r\nThere\'s an analogous discrepancy in numpy (which is probably where pandas inherited it from?):\r\n\r\n```python\r\n>>> import numpy as np\r\n>>> a = df.to_numpy()\r\n>>> a\r\narray([[1, 4],\r\n       [2, 5],\r\n       [3, 6]])\r\n>>> np.sum(a, axis=0)  # sum columns\r\narray([ 6, 15])\r\n>>> np.delete(a, 0, axis=1)  # delete first column\r\narray([[4],\r\n       [5],\r\n       [6]])\r\n```\r\n\r\nI just intuitively conceptualize these operations as working along the same axis, so it\'s hard for me to internalize that the value of the axis parameter is different in each case. Apparently, [I\'m not the only person to find this confusing](https://www.sharpsightlabs.com/blog/numpy-axes-explained/) (quoting from the article: "For example, in the np.sum() function, the axis parameter behaves in a way that many people think is counter intuitive").\r\n\r\nAt the same time, I can imagine that some people find this behavior completely natural (at the very least those who designed the API). And I understand that changing this in pandas while keeping the status quo in numpy would introduce a (probably) worse inconsistency, so I\'m not suggesting that.\r\n\r\n### Suggestion for improvement\r\n\r\nWhat I am suggesting is **reviewing the documentation of functions/methods using the `axis=` keyword argument** and (where applicable) **improving the description of what it controls in each case**. Pandas is typically used interactively, so documentation is easily accessible. If it contains useful hints on what each `axis` value does (and possibly why), it\'s not such a big problem if this behavior goes against some people\'s expectations.\r\n\r\n### Examples\r\n\r\nFor example, based on the [current master docs](https://pandas-docs.github.io/pandas-docs-travis/), the [description of the `axis` parameter for `drop`](https://pandas-docs.github.io/pandas-docs-travis/reference/api/pandas.DataFrame.drop.html#pandas.DataFrame.drop) does a good job at this:\r\n\r\n> axis : {0 or ‘index’, 1 or ‘columns’}, default 0\r\n> Whether to drop labels from the index (0 or ‘index’) or columns (1 or ‘columns’).\r\n\r\nThis makes it reasonably clear to me that if I specify `0`, I\'ll be removing rows, whereas `1` will result in removing columns.\r\n\r\nBy contrast, the [description of the `axis` parameter for `sum`](https://pandas-docs.github.io/pandas-docs-travis/reference/api/pandas.DataFrame.sum.html#pandas.DataFrame.sum) is somewhat too generic:\r\n\r\n> axis : {index (0), columns (1)}\r\n> Axis for the function to be applied on.\r\n\r\nBased on this, I could conclude (and have repeatedly done so) that if I want column sums, I need to "apply the function on columns", hence `axis=1` (which is wrong, cf. above).\r\n\r\nA revised description could look something like the following:\r\n\r\n> axis : {index (0), columns (1)}\r\n> Whether to collapse the index (0 or ‘index’), resulting in column sums, or the columns (1 or ‘columns’), resulting in row sums.'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29197',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29197/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29197/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29197/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/29197',
#   'id': 511631455,
#   'node_id': 'MDU6SXNzdWU1MTE2MzE0NTU=',
#   'number': 29197,
#   'title': 'MyPy Error Codes',
#   'user': {'login': 'WillAyd',
#    'id': 609873,
#    'node_id': 'MDQ6VXNlcjYwOTg3Mw==',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/609873?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/WillAyd',
#    'html_url': 'https://github.com/WillAyd',
#    'followers_url': 'https://api.github.com/users/WillAyd/followers',
#    'following_url': 'https://api.github.com/users/WillAyd/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/WillAyd/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/WillAyd/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/WillAyd/subscriptions',
#    'organizations_url': 'https://api.github.com/users/WillAyd/orgs',
#    'repos_url': 'https://api.github.com/users/WillAyd/repos',
#    'events_url': 'https://api.github.com/users/WillAyd/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/WillAyd/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2019-10-24T00:02:05Z',
#   'updated_at': '2019-10-24T09:49:24Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'body': 'mypy 0.73 came with support for error codes:\r\n\r\nhttp://mypy-lang.blogspot.com/2019/09/mypy-730-released.html\r\n\r\nI think we should add these to CI and update docs to require these going forward for any `type: ignore` statements\r\n\r\n@simonjayhawkins '},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29193',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29193/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29193/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29193/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/29193',
#   'id': 511542682,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0MzMxNzIxMDU2',
#   'number': 29193,
#   'title': 'Test For MultiIndex not contained item',
#   'user': {'login': 'gabriellm1',
#    'id': 26482095,
#    'node_id': 'MDQ6VXNlcjI2NDgyMDk1',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/26482095?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gabriellm1',
#    'html_url': 'https://github.com/gabriellm1',
#    'followers_url': 'https://api.github.com/users/gabriellm1/followers',
#    'following_url': 'https://api.github.com/users/gabriellm1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/gabriellm1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/gabriellm1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/gabriellm1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/gabriellm1/orgs',
#    'repos_url': 'https://api.github.com/users/gabriellm1/repos',
#    'events_url': 'https://api.github.com/users/gabriellm1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/gabriellm1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 71268330,
#     'node_id': 'MDU6TGFiZWw3MTI2ODMzMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/MultiIndex',
#     'name': 'MultiIndex',
#     'color': '207de5',
#     'default': False},
#    {'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2019-10-23T20:05:14Z',
#   'updated_at': '2019-10-24T06:47:29Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/29193',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/29193',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/29193.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/29193.patch'},
#   'body': '- [x] closes #21094\r\n- [ ] tests added / passed\r\n- [x] passes `black pandas`\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [ ] whatsnew entry\r\n\r\nI just made the test that was requested in this issue but in fact it isn\'t actually passing like mentioned there. Maybe my master is not updated for this. Should tests be added to whatsnew entry too?\r\n'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29192',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29192/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29192/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29192/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/29192',
#   'id': 511523724,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0MzMxNzA1NTU0',
#   'number': 29192,
#   'title': 'Removed generate_bins_generic',
#   'user': {'login': 'WillAyd',
#    'id': 609873,
#    'node_id': 'MDQ6VXNlcjYwOTg3Mw==',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/609873?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/WillAyd',
#    'html_url': 'https://github.com/WillAyd',
#    'followers_url': 'https://api.github.com/users/WillAyd/followers',
#    'following_url': 'https://api.github.com/users/WillAyd/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/WillAyd/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/WillAyd/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/WillAyd/subscriptions',
#    'organizations_url': 'https://api.github.com/users/WillAyd/orgs',
#    'repos_url': 'https://api.github.com/users/WillAyd/repos',
#    'events_url': 'https://api.github.com/users/WillAyd/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/WillAyd/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2019-10-23T19:24:21Z',
#   'updated_at': '2019-10-25T21:28:07Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/29192',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/29192',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/29192.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/29192.patch'},
#   'body': 'appears to be dead groupby code'}]

# %%
issues = pd.DataFrame(data, columns=['number', 'title', 'labels', 'state'])
issues
# Out:
#     number                                              title  \
# 0    29241             merge vs. join - unify parameter names
# 1    29240  Trying to use to_sql on dataframe with numpy.n...
# 2    29239  BENCH: Improve perf of rolling.Apply.time_rolling
# 3    29237              Replace _has_complex_internals #29227
# 4    29236      DOCS: Formatting Errors pandas.TimedeltaIndex
# 5    29235  Categories reordered to alphabetical when plot...
# 6    29234                     BUG: PeriodEngine doesn't work
# 7    29233                read_csv encode operation on source
# 8    29232                             CLN: assorted cleanups
# 9    29229  API/DOC: an ExtensionDtype.__from_arrow__ meth...
# 10   29228                CLN: prevent libreduction TypeError
# 11   29227  Replace _has_complex_internals with isinstance...
# 12   29226  Remove TestData in frame tests in multiple fil...
# 13   29224                                 Period index 29204
# 14   29223  CI: include pyarrow 0.15.0 / latest release in...
# 15   29220           Remove TestData in series tests indexing
# 16   29218        ENH: Show column name in assert_frame_equal
# 17   29217      In read_excel parse_date=False is not working
# 18   29216                        # noqa removal in code base
# 19   29214  CI/TST: Better information about the tests in ...
# 20   29213  BUG: pd.Dataframe.from_dict when first value i...
# 21   29212                        CI: Drop Python 3.5 support
# 22   29211  Adding test for assert_equal_index with empty ...
# 23   29208           REF: Dependency Structure Simplification
# 24   29205                 TYPING: Added types for some tests
# 25   29204  DOCS: docstrings formatting errors in pandas.P...
# 26   29203  Improve docs on what the axis= kwarg does in i...
# 27   29197                                   MyPy Error Codes
# 28   29193             Test For MultiIndex not contained item
# 29   29192                      Removed generate_bins_generic
#
#                                                labels state
# 0                                                  []  open
# 1                                                  []  open
# 2                                                  []  open
# 3   [{'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTE...  open
# 4                                                  []  open
# 5   [{'id': 78527356, 'node_id': 'MDU6TGFiZWw3ODUy...  open
# 6                                                  []  open
# 7   [{'id': 47229171, 'node_id': 'MDU6TGFiZWw0NzIy...  open
# 8                                                  []  open
# 9   [{'id': 76865106, 'node_id': 'MDU6TGFiZWw3Njg2...  open
# 10                                                 []  open
# 11  [{'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTE...  open
# 12                                                 []  open
# 13  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 14  [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 15  [{'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTE...  open
# 16  [{'id': 76865106, 'node_id': 'MDU6TGFiZWw3Njg2...  open
# 17  [{'id': 49254273, 'node_id': 'MDU6TGFiZWw0OTI1...  open
# 18                                                 []  open
# 19  [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 20                                                 []  open
# 21  [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 22  [{'id': 127685, 'node_id': 'MDU6TGFiZWwxMjc2OD...  open
# 23  [{'id': 127681, 'node_id': 'MDU6TGFiZWwxMjc2OD...  open
# 24  [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMj...  open
# 25  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 26  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 27  [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMj...  open
# 28  [{'id': 71268330, 'node_id': 'MDU6TGFiZWw3MTI2...  open
# 29  [{'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTE...  open

# %%
import sqlite3
query = """ CREATE TABLE test (a VARCHAR(20), b VARCHAR(20), c REAL, d INTEGER );"""

# %%
con = sqlite3.connect('mydata.sqlite')
con.execute(query)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-77-f57a3d81ed2e> in <module>
#       1 con = sqlite3.connect('mydata.sqlite')
# ----> 2 con.execute(query)
#       3 con.commit()
#
# OperationalError: table test already exists

# %%
con.commit()

# %%
data = [('Atlanta', 'Georgia', 1.25, 6),
 ('Tallahassee', 'Florida', 2.6, 3),
 ('Sacramento', 'California', 1.7, 5)]

# %%
stmt = "INSERT INTO test VALUES(?, ?, ?, ?)"
con.executemany(stmt, data)

# %%
con.commit()

# %%
cursor = con.execute('select * from test')
rows = cursor.fetchall()
rows
# Out:
# [('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5)]
